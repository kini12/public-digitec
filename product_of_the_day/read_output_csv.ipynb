# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %%
df = pd.read_csv("output.csv", encoding='latin-1', sep=",")

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
df.tail(30)
# Out:
#         ï»¿date        brand name_product  old_price  new_price  \
# 780  26.10.2022       Devolo          Kit     299.00     199.00
# 781  27.10.2022         Vava           4K   2,439.00   1,949.00
# 782  28.10.2022         Anda         seaT     459.00     369.00
# 783  29.10.2022      Disk2Go       Switch      32.00      19.90
# 784  30.10.2022          AOC      U27V4EA     295.00     199.00
# 785  31.10.2022        Apple       iPhone     720.00     639.00
# 786  01.11.2022           LG         QNED   1,741.00     999.00
# 787  02.11.2022         Acer        Nitro     359.00     199.00
# 788  03.11.2022     Logitech            G     154.00     119.00
# 789  04.11.2022         L33T       Energy     204.00     119.00
# 790  05.11.2022       Einova        Power     130.00      99.90
# 791  06.11.2022       Yamaha           RX     596.00     489.00
# 792  07.11.2022      Philips       329P1H     593.00     449.00
# 793  08.11.2022           HP         Omen   1,349.00     899.00
# ...

# %%
df.columns
# Out:
# Index(['ï»¿date', 'brand', 'name_product', 'old_price', 'new_price', 'detail',
#        'discount', '%'],
#       dtype='object')

# %%
new_cols = {'ï»¿date': 'date'}

# %%
df = df.rename(columns=new_cols)

# %%
discount = df.old_price - df.new_price
discount = discount.round(2)
max = df.old_price/100 
discount_pourcentage = discount / max

# %%
df["discount"]= discount
df["%"]=discount_pourcentage.round(2)

# %%
data1 = df["%"]
data2 = df["discount"]
Date = df["date"]

# %%
df.mean().round(2)
# Out:
# old_price   542.62
# new_price   416.44
# discount    127.31
# %            26.00
# dtype: float64

# %%
#creation du df avec % comme index, du plus grand au plus petit
df.sort_values(by = "%", ascending = False).head(50)
# Out:
#            date       brand   name_product  old_price  new_price  \
# 109  10.10.2020     Tp-Link        Archer       99.00      25.00
# 601  20.04.2022   Energizer            Kit      75.00      29.00
# 543  19.02.2022     Philips            TAT     121.00      49.00
# 434  26.09.2021      Norton         Deluxe      48.00      20.00
# 497  01.01.2022       Aukey            Pro      55.00      25.00
# 670  29.06.2022        Sony             WF     135.00      66.00
# 143  15.11.2020      OtterB      Batterie       89.00      44.00
# 398  18.08.2021   Microsoft         Office     149.00      74.00
# 418  09.09.2021         AOC           AGON     599.00     299.00
# 58   20.08.2020     Lenovo    ThinkCentre    1,399.00     699.00
# 686  16.07.2022         PNY            Pro     198.00      99.00
# 11   30.06.2020     Samsung        Galaxy    1,349.00     699.00
# 7    26.06.2020     Klipsch            T5      189.00      99.00
# ...

# %%
#moyenne des %
moy = df["%"].mean()
moy = str(round(moy, 2))
moy
# Out:
# '26.0'

# %%
df["date"]
# Out:
# 0      18.06.2020
# 1      19.06.2020
# 2      20.06.2020
# 3      21.06.2020
# 4      22.06.2020
#           ...
# 805    20.11.2022
# 806    21.11.2022
# 807    29.11.2022
# 808    25.12.2022
# 809    26.12.2022
# Name: date, Length: 810, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          810 non-null    object
#  1   brand         810 non-null    object
#  2   name_product  810 non-null    object
#  3   old_price     804 non-null    float64
#  4   new_price     810 non-null    float64
#  5   detail        545 non-null    object
#  6   discount      804 non-null    float64
#  7   %             804 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 50.8+ KB

# %%
df["date"] = pd.to_datetime(df["date"], format="%d.%m.%Y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          810 non-null    datetime64[ns]
#  1   brand         810 non-null    object
#  2   name_product  810 non-null    object
#  3   old_price     804 non-null    float64
#  4   new_price     810 non-null    float64
#  5   detail        545 non-null    object
#  6   discount      804 non-null    float64
#  7   %             804 non-null    float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 50.8+ KB

# %%
# filer by year
mask = (df['date'] > '2020-01-01') & (df['date'] < '2021-01-01')
mask2 = (df['date'] > '2021-01-01') & (df['date'] < '2022-01-01')
mask3 = (df['date'] > '2022-01-01') & (df['date'] < '2023-01-01')
filt20=df.loc[mask]
filt21=df.loc[mask2]
filt22=df.loc[mask3]

# %%
filt20
# Out:
#           date       brand name_product  old_price  new_price  \
# 0   2020-06-18     Brother          MFC     433.00     299.00
# 1   2020-06-19   Libratone        TRACK     274.00     199.00
# 2   2020-06-20      Devolo         kit      164.00     129.00
# 3   2020-06-21      Suunto        Gift      585.00     449.00
# 4   2020-06-22   Microsoft         365       82.00      65.00
# ..         ...         ...          ...        ...        ...
# 183 2020-12-27   Energizer          Max      59.70      33.00
# 184 2020-12-28          LG   OLED55GX6    1,699.00   1,499.00
# 185 2020-12-29        Arlo         Pro    1,086.00     849.00
# 186 2020-12-30    Logitech        Craft     153.00      99.00
# 187 2020-12-31        Asus         Vivo     949.00     699.00
#
#                                                 detail  discount     %
# 0    -L8690CDW WiFi Laser/LED Couleur Impression re...    134.00 30.95
# 1                          Air+ Bundle In-Ear Noir ANC     75.00 27.37
# ...

# %%
#creation du df avec % comme index, du plus grand au plus petit
filt20.sort_values(by = "%", ascending = False).head(5)
# Out:
#           date    brand  name_product  old_price  new_price  \
# 109 2020-10-10  Tp-Link       Archer       99.00      25.00
# 143 2020-11-15   OtterB     Batterie       89.00      44.00
# 58  2020-08-20  Lenovo   ThinkCentre    1,399.00     699.00
# 11  2020-06-30  Samsung       Galaxy    1,349.00     699.00
# 7   2020-06-26  Klipsch           T5      189.00      99.00
#
#                                                 detail  discount     %
# 109                                              MR600     74.00 74.75
# 143  de secours exterieure + LifeProof cable A-C US...     45.00 50.56
# 58         M920t  Intel Core i5-9400  16Go  512Go  SSD    700.00 50.04
# 11   S10+ 12GB 1000Go Ceramic White 6.40 Double SIM...    650.00 48.18
# 7                            True wireless In-Ear Noir     90.00 47.62

# %%
filt21.sort_values(by = "%", ascending = False).head(5)
# Out:
#           date      brand name_product  old_price  new_price detail  discount  \
# 434 2021-09-26     Norton       Deluxe      48.00      20.00    NaN     28.00
# 398 2021-08-18  Microsoft       Office     149.00      74.00    NaN     75.00
# 418 2021-09-09        AOC         AGON     599.00     299.00    NaN    300.00
# 350 2021-06-25     Norton      Premium      55.00      29.00    NaN     26.00
# 402 2021-08-22    Linksys        Velop     456.00     249.00    NaN    207.00
#
#         %
# 434 58.33
# 398 50.34
# 418 50.08
# 350 47.27
# 402 45.39

# %%
filt22.sort_values(by = "%", ascending = False).head(5)
# Out:
#           date      brand name_product  old_price  new_price  \
# 600 2022-04-20  Energizer          Kit      75.00      29.00
# 542 2022-02-19    Philips          TAT     121.00      49.00
# 667 2022-06-29       Sony           WF     135.00      66.00
# 682 2022-07-16        PNY          Pro     198.00      99.00
# 694 2022-07-29       Acer        Nitro     189.00      99.00
#
#                                       detail  discount     %
# 600               Max Alcaline 60 pcs AAA AA     46.00 61.33
# 542                                 8505 ANC     72.00 59.50
# 667                  -1000XM3ANC111100:00:00     69.00 51.11
# 682    Elite1000 Go USB Type A 3.04100:00:00     99.00 50.00
# 694  VG240Y1920 x 1080 pixels 24 19300:00:00     90.00 47.62

# %%
len(filt20)
# Out:
# 188

# %%
len(filt21)
# Out:
# 308

# %%
len(filt22)
# Out:
# 282

# %%
filt20["%"].mean()
# Out:
# 26.626914893617023

# %%
filt21["%"].mean()
# Out:
# 25.359545454545458

# %%
filt22["%"].mean()
# Out:
# 26.24748226950355

# %%
data1 = filt20.sort_values(by = "%", ascending = False).head(5)
data2 = filt21.sort_values(by = "%", ascending = False).head(5)
data3 = filt22.sort_values(by = "%", ascending = False).head(5)

# %%
frames = [data1,data2,data3]

# %%
result = pd.concat(frames)

# %%
result
# Out:
#           date      brand  name_product  old_price  new_price  \
# 109 2020-10-10    Tp-Link       Archer       99.00      25.00
# 143 2020-11-15     OtterB     Batterie       89.00      44.00
# 58  2020-08-20    Lenovo   ThinkCentre    1,399.00     699.00
# 11  2020-06-30    Samsung       Galaxy    1,349.00     699.00
# 7   2020-06-26    Klipsch            T5     189.00      99.00
# 434 2021-09-26     Norton        Deluxe      48.00      20.00
# 398 2021-08-18  Microsoft        Office     149.00      74.00
# 418 2021-09-09        AOC          AGON     599.00     299.00
# 350 2021-06-25     Norton       Premium      55.00      29.00
# 402 2021-08-22    Linksys         Velop     456.00     249.00
# 600 2022-04-20  Energizer           Kit      75.00      29.00
# 542 2022-02-19    Philips           TAT     121.00      49.00
# 667 2022-06-29       Sony            WF     135.00      66.00
# 682 2022-07-16        PNY           Pro     198.00      99.00
# ...

# %%
discount = result["discount"]
per_cent = result["%"]
brand = result["brand"]

# %%
result.hist()



plt.show()
